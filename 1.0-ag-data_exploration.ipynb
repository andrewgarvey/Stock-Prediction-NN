# %% [markdown]
# # Data exploration File for 823 Assign A2
#
# ## Author: Andrew Garvey
# ## Date : Dec 2nd, 2018

# %% [markdown]
# ## SETUP

# %%
#setup packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setup dir
inputdir = 'D:\QUEENS MMAI\823 Finance\Assign\Assign2\Input'
outputdir = 'D:\QUEENS MMAI\823 Finance\Assign\Assign2\Output'

# %% [markdown]
# ## IMPORT

# %%
## Read file(s) / directory management
os.chdir(inputdir)
train = pd.read_excel('A2trainData_MMAI.xlsx')
os.chdir(outputdir)

# %% [markdown]
# ## BASIC EXPLORING of TRAIN

# %%
## head 
train.head()
# Out:
#    Year       EPS  Liquidity  Profitability  Productivity  Leverage Ratio  \
# 0  1993 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 1  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 2  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 3  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 4  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
#
#    Market Book Ratio  Tobin's Q   b_umd  Excess Return from Risk Model  \
# 0         120.487587   1.097465 -0.2185                       0.063698
# 1         120.487587   1.097465 -0.2014                       0.054996
# 2         120.487587   1.097465 -0.1991                      -0.024033
# 3         120.487587   1.097465 -0.1895                      -0.087586
# 4         120.487587   1.097465 -0.1666                      -0.173001
#
#     b_hml   alpha   b_smb   Returns   b_mkt  Total Volatility  Output Return %
# 0 -0.1232  0.0003  0.3953  0.068493  0.7534          0.084012          -1.9868
# 1 -0.0908  0.0012  0.3554  0.076923  0.7558          0.082222           8.7838
# 2 -0.0852  0.0015  0.3360 -0.029762  0.7544          0.081773           8.1988
# 3 -0.0755  0.0011  0.3332 -0.122699  0.7639          0.082060           8.6207
# 4 -0.0590  0.0006  0.3310 -0.170213  0.7556          0.082041           1.0582

# %%
## Summary
train.describe().transpose()
# Out:
#                                  count         mean          std  \
# Year                           94859.0  1998.491783     4.607276
# EPS                            94859.0     1.302542    21.918165
# Liquidity                      94859.0     0.195645     0.205823
# Profitability                  94859.0     0.275314     0.734245
# Productivity                   94859.0     0.100757     0.151144
# Leverage Ratio                 94859.0     1.077061    35.615657
# Market Book Ratio              94859.0   799.047340  4994.864432
# Tobin's Q                      94859.0     1.813025     1.892319
# b_umd                          94859.0    -0.093917     0.252912
# Excess Return from Risk Model  94859.0     0.002913     0.107143
# b_hml                          94859.0     0.244187     0.447290
# alpha                          94859.0     0.002931     0.006202
# b_smb                          94859.0     0.479678     0.606994
# Returns                        94859.0     0.013335     0.113598
# b_mkt                          94859.0     0.961640     0.298828
# Total Volatility               94859.0     0.104693     0.039717
# Output Return %                94859.0     1.389770    11.778750
#
#                                         min          25%          50%  \
# Year                            1989.000000  1995.000000  1999.000000
# EPS                            -2005.961353     0.509960     1.404610
# Liquidity                         -2.314604     0.037265     0.168070
# Profitability                    -41.429463     0.130109     0.296951
# Productivity                      -1.319534     0.057215     0.091516
# Leverage Ratio                  -470.178325     0.176964     0.529999
# Market Book Ratio             -61482.280405    18.880120    79.637795
# Tobin's Q                          0.407340     1.140711     1.394652
# b_umd                             -1.671500    -0.232100    -0.085500
# Excess Return from Risk Model     -0.724585    -0.050177    -0.001346
# b_hml                             -2.795900    -0.035700     0.286600
# alpha                             -0.028700    -0.000700     0.002500
# b_smb                             -0.979800     0.040250     0.412100
# Returns                           -0.702934    -0.043532     0.008333
# b_mkt                             -0.254200     0.755700     0.962300
# Total Volatility                   0.041888     0.077781     0.095431
# Output Return %                  -75.925900    -4.220100     0.895500
#
#                                        75%            max
# Year                           2003.000000    2005.000000
# EPS                               2.408461     168.308411
# Liquidity                         0.326155       1.000000
# Profitability                     0.487101       1.717179
# Productivity                      0.136319       5.143878
# Leverage Ratio                    0.984877    3096.639175
# Market Book Ratio               324.076938  286051.684211
# Tobin's Q                         1.932979      71.221002
# b_umd                             0.059600       1.406500
# Excess Return from Risk Model     0.049335       3.402935
# b_hml                             0.551600       2.016100
# alpha                             0.006000       0.058300
# b_smb                             0.846900       4.598900
# Returns                           0.062609       3.659070
# b_mkt                             1.170500       2.120800
# Total Volatility                  0.122968       0.470094
# Output Return %                   6.232400    1100.000000

# %%
## Count the missings
train.isna().sum()
# Out:
# Year                             0
# EPS                              0
# Liquidity                        0
# Profitability                    0
# Productivity                     0
# Leverage Ratio                   0
# Market Book Ratio                0
# Tobin's Q                        0
# b_umd                            0
# Excess Return from Risk Model    0
# b_hml                            0
# alpha                            0
# b_smb                            0
# Returns                          0
# b_mkt                            0
# Total Volatility                 0
# Output Return %                  0
# dtype: int64

# %% [markdown]
# ## Correlation Matrix

# %%
plt.clf()
f, ax = plt.subplots(figsize=(15, 15))
corr = train.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, ax=ax, annot =True)
plt.savefig('1.0-ag-Correlation Matrix.png')

# %% [markdown]
# ## Output

# %%
returns=train.loc[:,'Output Return %']
returns.describe().transpose()
# Out:
# count    94859.00000
# mean         1.38977
# std         11.77875
# min        -75.92590
# 25%         -4.22010
# 50%          0.89550
# 75%          6.23240
# max       1100.00000
# Name: Output Return %, dtype: float64

# %%
Z = (returns-np.mean(returns))/np.std(returns)
Z = Z.sort_values()

Z.head()
# Out:
# 37293   -6.564031
# 32733   -6.043243
# 94630   -5.989867
# 1332    -5.891129
# 79103   -5.777933
# Name: Output Return %, dtype: float64

# %%
Z.tail()
# Out:
# 71044    17.046400
# 63003    17.230971
# 77478    17.294475
# 24703    17.514873
# 10268    93.271018
# Name: Output Return %, dtype: float64

# %% [markdown]
# yeah we got a single value ~93 std away, and the next one is ~17 away...
#
# thats almost certainly a typo or something equally crazy, should remove it

# %%
plt.clf()
plt.ylabel(' Frequency')
plt.xlabel('Output Return %')
plt.title('Frequency of Output Return %s')
plt.hist(returns, bins=100, range= (-50,50))
plt.savefig('1.0-ag-Output Return %.png')
